# %%
# Import Libraries 
from plantcv import plantcv as pcv
from plant_sqlite import select_plants

# %%
plants = select_plants()

for plant in plants:
	pcv.plot_image(plant["raw_image"])
	pcv.plot_image(plant["binary_image"])
	pcv.plot_image(plant["masked_image"])
	pcv.plot_image(plant["pruned_image"])
	pcv.plot_image(plant["branches_image"])
	pcv.plot_image(plant["tips_image"])
	pcv.plot_image(plant["height_image"])
	pcv.plot_image(plant["skeleton_image"])
	print(plant["metadata"])
# Out:
# {'default': {'branch_pts': {'trait': 'list of branch-point coordinates identified from a skeleton', 'method': 'plantcv.plantcv.morphology.find_branch_pts', 'scale': 'pixels', 'datatype': "<class 'list'>", 'value': [[594, 772], [594, 769], [612, 722], [580, 721], [580, 717], [580, 713], [616, 709], [580, 707], [580, 703], [639, 696], [580, 693], [644, 692], [635, 692], [647, 689], [634, 689], [632, 689], [635, 686], [594, 680], [573, 680], [581, 679], [585, 674], [604, 673], [573, 673], [571, 671], [654, 666], [590, 666], [677, 665], [593, 663], [606, 658], [601, 658], [606, 654], [610, 653], [613, 652], [686, 651], [684, 650], [680, 650], [619, 648], [626, 645], [637, 642], [635, 642], [583, 641], [644, 639], [639, 639], [649, 637], [587, 636], [676, 635], [666, 635], [639, 635], [655, 634], [681, 633], [689, 632], [640, 632], [662, 631], [686, 630], [641, 627], [640, 620], [598, 617], [640, 613], [602, 610], [642, 608], [682, 607], [641, 601], [685, 600], [641, 598], [668, 594], [65
# ...
